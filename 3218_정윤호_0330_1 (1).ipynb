# %% [markdown]
# 3218_정윤호_0330_1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y, m, d = input().split('.')
print(d,m,y,sep='-')
# Out:
# 2020.3.4
# 4-3-2020

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a, b = input().split('-')

print(a+b)
# Out:
# 000907-1121112
# 0009071121112
